# %%
import os
import pandas as pd
import numpy as np
from clearbox_engine import Dataset
# Out:
# /usr/local/lib/python3.9/site-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /usr/local/lib/python3.9/site-packages/clearbox_engine/metrics/privacy/gower_matrix_c.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# In file included from /usr/local/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /usr/local/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from /root/.pyxbld/temp.linux-x86_64-3.9/usr/local/lib/python3.9/site-packages/clearbox_engine/metrics/privacy/gower_matrix_c.c:1240:
# /usr/local/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~

# %%
#  Define license key
LICENSE_KEY = "licensekeyoverride2023@"

#  Load Original Dataset
file_path = "https://raw.githubusercontent.com/gillus/Corso_MLOps/refs/heads/main/data"

train_dataset = Dataset.from_csv(
    os.path.join(file_path, "adult_training.csv"),
    target_column="income",
    regression=False
)

# %%
def identify_discrepancies(df, target_column="income", positive_outcome=">50K"):

    sensitive_attributes = ["sex", "race", "marital_status", "age"]
    discrepancies = []

    for attr in sensitive_attributes:
        # Calculate positive outcome rate for each subgroup
        subgroup_counts = df.groupby(attr)[target_column].count()
        subgroup_positive_counts = df[df[target_column] == positive_outcome].groupby(attr)[target_column].count()
        positive_rate = (subgroup_positive_counts / subgroup_counts).fillna(0)

        # Calculate disparity from the average positive outcome rate
        avg_positive_rate = positive_rate.mean()
        disparity = positive_rate - avg_positive_rate

        # Append results
        for group, rate in positive_rate.items():
            discrepancies.append({
                "Attribute": attr,
                "Group": group,
                "Positive Rate": rate,
                "Disparity from Average": disparity[group]
            })

    # Convert to DataFrame for easier viewing
    discrepancy_df = pd.DataFrame(discrepancies)
    return discrepancy_df.sort_values(by="Disparity from Average")

# %%
# Convert the Dataset object to a DataFrame
train_df = pd.DataFrame(
    data=train_dataset.get_x(),
    columns=train_dataset.x_columns()
)

# Add the target column to the DataFrame
train_df["income"] = train_dataset.get_y()

# Now you can pass train_df to the identify_discrepancies function
discrepancy_summary = identify_discrepancies(train_df)

# Set display options to show the entire DataFrame
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Don't limit the display width
pd.set_option('display.max_colwidth', None)  # Don't truncate column content

# Print the full DataFrame
print(discrepancy_summary)
# Out:
#          Attribute               Group  Positive Rate  Disparity from Average
# 81             age                  88       0.000000               -0.234250
# 80             age                  86       0.000000               -0.234250
# 79             age                  85       0.000000               -0.234250
# 14             age                  20       0.000000               -0.234250
# 76             age                  82       0.000000               -0.234250
# 12             age                  18       0.000000               -0.234250
# 11             age                  17       0.000000               -0.234250
# 13             age                  19       0.001684               -0.232566
# 15             age                  21       0.004831               -0.229419
# 17             age                  23       0.014563               -0.219687
# 16             age                  22       0.017804               -0.216446
# 18             age                  24       0.039894               -0.194356
# 74             age                  80       0.062500               -0.171750
# 19             age                  25       0.066333               -0.167917
# 70             age                  76       0.068966               -0.165284
# 20             age                  26       0.081879               -0.152371
# 21             age                  27       0.095057               -0.139193
# 8   marital_status       Never-Married       0.048324               -0.126539
# 78             age                  84       0.125000               -0.109250
# 0              sex              Female       0.113678               -0.100079
# 22             age                  28       0.143564               -0.090685
# 5             race               Other       0.090909               -0.085197
# 71             age                  77       0.150000               -0.084250
# 66             age                  72       0.150000               -0.084250
# 75             age                  81       0.153846               -0.080404
# 10  marital_status             Widowed       0.096735               -0.078128
# 9   marital_status           Separated       0.099402               -0.075461
# 23             age                  29       0.169251               -0.064999
# 69             age                  75       0.176471               -0.057779
# 2             race  Amer-Indian-Eskimo       0.118881               -0.057225
# 67             age                  73       0.183673               -0.050576
# 63             age                  69       0.187500               -0.046750
# 4             race               Black       0.129925               -0.046180
# 82             age                  90       0.200000               -0.034250
# 24             age                  30       0.205412               -0.028838
# 25             age                  31       0.207991               -0.026259
# 65             age                  71       0.222222               -0.012028
# 27             age                  33       0.225806               -0.008443
# 59             age                  65       0.227941               -0.006309
# 26             age                  32       0.235741                0.001492
# 62             age                  68       0.244444                0.010195
# 29             age                  35       0.247585                0.013335
# 64             age                  70       0.250000                0.015750
# 56             age                  62       0.262911                0.028661
# 57             age                  63       0.263441                0.029191
# 58             age                  64       0.265896                0.031646
# 60             age                  66       0.272727                0.038477
# 28             age                  34       0.278708                0.044458
# 61             age                  67       0.288288                0.054039
# 30             age                  36       0.300469                0.066220
# 55             age                  61       0.312741                0.078492
# 68             age                  74       0.315789                0.081540
# 6             race               White       0.263718                0.087612
# 54             age                  60       0.326087                0.091837
# 50             age                  56       0.332362                0.098112
# 1              sex                Male       0.313837                0.100079
# 3             race  Asian-Pac-Islander       0.277095                0.100989
# 34             age                  40       0.342484                0.108234
# 52             age                  58       0.343023                0.108773
# 33             age                  39       0.343511                0.109262
# 32             age                  38       0.343869                0.109619
# 31             age                  37       0.346618                0.112369
# 49             age                  55       0.347150                0.112900
# 35             age                  41       0.352406                0.118156
# 36             age                  42       0.353576                0.119326
# 72             age                  78       0.357143                0.122893
# 37             age                  43       0.358008                0.123758
# 43             age                  49       0.363964                0.129714
# 53             age                  59       0.373494                0.139244
# 51             age                  57       0.376855                0.142605
# 38             age                  44       0.392045                0.157796
# 39             age                  45       0.398017                0.163767
# 40             age                  46       0.399437                0.165188
# 42             age                  48       0.399618                0.165368
# 73             age                  79       0.400000                0.165750
# 77             age                  83       0.400000                0.165750
# 46             age                  52       0.402198                0.167948
# 47             age                  53       0.408482                0.174232
# 41             age                  47       0.408492                0.174242
# 45             age                  51       0.411559                0.177309
# 48             age                  54       0.426396                0.192146
# 44             age                  50       0.438261                0.204011
# 7   marital_status             Married       0.454991                0.280128

# %% [markdown]
#  Masks for Synthetic Data Generation:
#
# 1️⃣ Female + Older Age (85+):
# mask = (features_df["sex"] == "Female") & (features_df["age"] >= 85) & (labels_array == ">50K")
#
# 2️⃣ Female + Never-Married:
# mask = (features_df["sex"] == "Female") & (features_df["marital_status"] == "Never-Married") & (labels_array == ">50K")
#
# 3️⃣ Black + Female:
# mask = (features_df["race"] == "Black") & (features_df["sex"] == "Female") & (labels_array == ">50K")
#
# 4️⃣ Black + Never-Married:
# mask = (features_df["race"] == "Black") & (features_df["marital_status"] == "Never-Married") & (labels_array == ">50K")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def identify_intersectional_discrepancies(df, target_column="income", positive_outcome=">50K"):
 
    # Define the intersectional attributes you want to analyze
    intersectional_attributes = [
        ("sex", "race"),
        ("sex", "marital_status"),
        ("race", "marital_status"),
        ("sex", "age")
    ]

    discrepancies = []

    for attrs in intersectional_attributes:
        # Create a combined attribute column for intersectional groups
        df["Intersectional Group"] = df.loc[:, list(attrs)].apply(lambda x: " + ".join(x.astype(str)), axis=1)

        # Calculate positive outcome rate for each intersectional group
        subgroup_counts = df.groupby("Intersectional Group")[target_column].count()
        subgroup_positive_counts = df[df[target_column] == positive_outcome].groupby("Intersectional Group")[target_column].count()
        positive_rate = (subgroup_positive_counts / subgroup_counts).fillna(0)

        # Calculate disparity from the average positive outcome rate
        avg_positive_rate = positive_rate.mean()
        disparity = positive_rate - avg_positive_rate

        # Append results
        for group, rate in positive_rate.items():
            discrepancies.append({
                "Intersectional Group": group,
                "Attributes": " + ".join(attrs),
                "Positive Rate": rate,
                "Disparity from Average": disparity[group]
            })

    # Convert to DataFrame for easier viewing
    discrepancy_df = pd.DataFrame(discrepancies)
    return discrepancy_df.sort_values(by="Disparity from Average")

# %%
# Convert the Dataset object to a DataFrame
train_df = pd.DataFrame(
    data=train_dataset.get_x(),
    columns=train_dataset.x_columns()
)

# Add the target column to the DataFrame
train_df["income"] = train_dataset.get_y()

# Run the intersectional discrepancy function
intersectional_discrepancy_summary = identify_intersectional_discrepancies(train_df)

# Set display options to show the entire DataFrame
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# Print the full intersectional discrepancy summary
print(intersectional_discrepancy_summary)
# Out:
#                    Intersectional Group             Attributes  Positive Rate  \
# 38                          Female + 17              sex + age       0.000000
# 90                          Female + 69              sex + age       0.000000
# 109                           Male + 17              sex + age       0.000000
# 107                         Female + 88              sex + age       0.000000
# 106                         Female + 86              sex + age       0.000000
# 101                         Female + 80              sex + age       0.000000
# 105                         Female + 85              sex + age       0.000000
# 104                         Female + 84              sex + age       0.000000
# 110                           Male + 18              sex + age       0.000000
# 103                         Female + 82              sex + age       0.000000
# 39                          Female + 18              sex + age       0.000000
# 40                          Female + 19              sex + age       0.000000
# 41                          Female + 20              sex + age       0.000000
# 96                          Female + 75              sex + age       0.000000
# 97                          Female + 76              sex + age       0.000000
# 98                          Female + 77              sex + age       0.000000
# 99                          Female + 78              sex + age       0.000000
# 102                         Female + 81              sex + age       0.000000
# 178                           Male + 88              sex + age       0.000000
# 100                         Female + 79              sex + age       0.000000
# 86                          Female + 65              sex + age       0.000000
# 177                           Male + 85              sex + age       0.000000
# 174                           Male + 82              sex + age       0.000000
# 112                           Male + 20              sex + age       0.000000
# 113                           Male + 21              sex + age       0.002907
# 111                           Male + 19              sex + age       0.003344
# 44                          Female + 23              sex + age       0.005900
# 42                          Female + 21              sex + age       0.007220
# 43                          Female + 22              sex + age       0.013289
# 115                           Male + 23              sex + age       0.020619
# 114                           Male + 22              sex + age       0.021448
# 45                          Female + 24              sex + age       0.028470
# 11               Female + Never-Married   sex + marital_status       0.037801
# 116                           Male + 24              sex + age       0.046709
# 92                          Female + 71              sex + age       0.047619
# 47                          Female + 26              sex + age       0.048327
# 46                          Female + 25              sex + age       0.050505
# 91                          Female + 70              sex + age       0.055556
# 15                 Male + Never-Married   sex + marital_status       0.056705
# 48                          Female + 27              sex + age       0.059259
# 13                     Female + Widowed   sex + marital_status       0.059767
# 12                   Female + Separated   sex + marital_status       0.061361
# 94                          Female + 73              sex + age       0.062500
# 93                          Female + 72              sex + age       0.066667
# 33                      Other + Widowed  race + marital_status       0.000000
# 32                    Other + Separated  race + marital_status       0.000000
# 21         Amer-Indian-Eskimo + Widowed  race + marital_status       0.000000
# 117                           Male + 25              sex + age       0.075697
# 29                      Black + Widowed  race + marital_status       0.009346
# 3                        Female + Other             sex + race       0.045977
# 85                          Female + 64              sex + age       0.087719
# 82                          Female + 61              sex + age       0.088235
# 83                          Female + 62              sex + age       0.089744
# 31                Other + Never-Married  race + marital_status       0.023810
# 172                           Male + 80              sex + age       0.090909
# 27                Black + Never-Married  race + marital_status       0.026734
# 89                          Female + 68              sex + age       0.093750
# 2                        Female + Black             sex + race       0.060758
# 118                           Male + 26              sex + age       0.100840
# 76                          Female + 55              sex + age       0.104839
# 87                          Female + 66              sex + age       0.105263
# 49                          Female + 28              sex + age       0.106227
# 51                          Female + 30              sex + age       0.110672
# 168                           Male + 76              sex + age       0.111111
# 119                           Male + 27              sex + age       0.113680
# 78                          Female + 57              sex + age       0.117647
# 52                          Female + 31              sex + age       0.117871
# 35                White + Never-Married  race + marital_status       0.051518
# 19   Amer-Indian-Eskimo + Never-Married  race + marital_status       0.052632
# 23   Asian-Pac-Islander + Never-Married  race + marital_status       0.054140
# 50                          Female + 29              sex + age       0.125490
# 28                    Black + Separated  race + marital_status       0.060322
# 84                          Female + 63              sex + age       0.127273
# 77                          Female + 56              sex + age       0.131313
# 53                          Female + 32              sex + age       0.133047
# 55                          Female + 34              sex + age       0.134454
# 66                          Female + 45              sex + age       0.140845
# 0           Female + Amer-Indian-Eskimo             sex + race       0.102804
# 65                          Female + 44              sex + age       0.142857
# 54                          Female + 33              sex + age       0.144681
# 20       Amer-Indian-Eskimo + Separated  race + marital_status       0.083333
# 67                          Female + 46              sex + age       0.152074
# 95                          Female + 74              sex + age       0.153846
# 88                          Female + 67              sex + age       0.153846
# 16                     Male + Separated   sex + marital_status       0.155536
# 8                          Male + Other             sex + race       0.118056
# 57                          Female + 36              sex + age       0.156716
# 81                          Female + 60              sex + age       0.157143
# 56                          Female + 35              sex + age       0.160000
# 4                        Female + White             sex + race       0.122989
# 120                           Male + 28              sex + age       0.162617
# 70                          Female + 49              sex + age       0.163636
# 5             Male + Amer-Indian-Eskimo             sex + race       0.128492
# 36                    White + Separated  race + marital_status       0.106017
# 68                          Female + 47              sex + age       0.173077
# 73                          Female + 52              sex + age       0.173228
# 75                          Female + 54              sex + age       0.173469
# 72                          Female + 51              sex + age       0.175000
# 1           Female + Asian-Pac-Islander             sex + race       0.139456
# 37                      White + Widowed  race + marital_status       0.111111
# 59                          Female + 38              sex + age       0.183857
# 61                          Female + 40              sex + age       0.185484
# 80                          Female + 59              sex + age       0.186047
# 62                          Female + 41              sex + age       0.188940
# 121                           Male + 29              sex + age       0.190751
# 58                          Female + 37              sex + age       0.196347
# 69                          Female + 48              sex + age       0.200000
# 108                         Female + 90              sex + age       0.200000
# 179                           Male + 90              sex + age       0.200000
# 71                          Female + 50              sex + age       0.200000
# 164                           Male + 72              sex + age       0.200000
# 63                          Female + 42              sex + age       0.200913
# 79                          Female + 58              sex + age       0.204082
# 60                          Female + 39              sex + age       0.206478
# 74                          Female + 53              sex + age       0.209302
# 25         Asian-Pac-Islander + Widowed  race + marital_status       0.142857
# 24       Asian-Pac-Islander + Separated  race + marital_status       0.144068
# 169                           Male + 77              sex + age       0.230769
# 7                          Male + Black             sex + race       0.198166
# 167                           Male + 75              sex + age       0.240000
# 64                          Female + 43              sex + age       0.240741
# 165                           Male + 73              sex + age       0.242424
# 122                           Male + 30              sex + age       0.248214
# 123                           Male + 31              sex + age       0.248299
# 176                           Male + 84              sex + age       0.250000
# 125                           Male + 33              sex + age       0.257475
# 161                           Male + 69              sex + age       0.263158
# 30                      Other + Married  race + marital_status       0.206522
# 17                       Male + Widowed   sex + marital_status       0.276596
# 18         Amer-Indian-Eskimo + Married  race + marital_status       0.211009
# 124                           Male + 32              sex + age       0.278777
# 127                           Male + 35              sex + age       0.280265
# 173                           Male + 81              sex + age       0.285714
# 155                           Male + 63              sex + age       0.320611
# 162                           Male + 70              sex + age       0.326087
# 160                           Male + 68              sex + age       0.327586
# 163                           Male + 71              sex + age       0.333333
# 126                           Male + 34              sex + age       0.336120
# 157                           Male + 65              sex + age       0.340659
# 156                           Male + 64              sex + age       0.353448
# 159                           Male + 67              sex + age       0.361111
# 158                           Male + 66              sex + age       0.361111
# 154                           Male + 62              sex + age       0.362963
# 9                          Male + White             sex + race       0.325313
# 128                           Male + 36              sex + age       0.366438
# 6             Male + Asian-Pac-Islander             sex + race       0.344426
# 152                           Male + 60              sex + age       0.383495
# 153                           Male + 61              sex + age       0.392670
# 150                           Male + 58              sex + age       0.398374
# 175                           Male + 83              sex + age       0.400000
# 166                           Male + 74              sex + age       0.400000
# 129                           Male + 37              sex + age       0.400657
# 135                           Male + 43              sex + age       0.406072
# 131                           Male + 39              sex + age       0.406308
# 130                           Male + 38              sex + age       0.406690
# 148                           Male + 56              sex + age       0.413934
# 133                           Male + 41              sex + age       0.416667
# 134                           Male + 42              sex + age       0.417625
# 132                           Male + 40              sex + age       0.417795
# 151                           Male + 59              sex + age       0.439024
# 26                      Black + Married  race + marital_status       0.375489
# 141                           Male + 49              sex + age       0.448718
# 14                       Male + Married   sex + marital_status       0.452835
# 170                           Male + 78              sex + age       0.454545
# 147                           Male + 55              sex + age       0.461832
# 149                           Male + 57              sex + age       0.464286
# 10                     Female + Married   sex + marital_status       0.473190
# 140                           Male + 48              sex + age       0.487603
# 136                           Male + 44              sex + age       0.488189
# 145                           Male + 53              sex + age       0.489028
# 144                           Male + 52              sex + age       0.490854
# 171                           Male + 79              sex + age       0.500000
# 143                           Male + 51              sex + age       0.503650
# 138                           Male + 46              sex + age       0.508097
# 137                           Male + 45              sex + age       0.509128
# 146                           Male + 54              sex + age       0.510135
# 139                           Male + 47              sex + age       0.511579
# 142                           Male + 50              sex + age       0.522353
# 34                      White + Married  race + marital_status       0.462922
# 22         Asian-Pac-Islander + Married  race + marital_status       0.477376
#
#      Disparity from Average
# 38                -0.196803
# 90                -0.196803
# 109               -0.196803
# 107               -0.196803
# 106               -0.196803
# 101               -0.196803
# 105               -0.196803
# 104               -0.196803
# 110               -0.196803
# 103               -0.196803
# 39                -0.196803
# 40                -0.196803
# 41                -0.196803
# 96                -0.196803
# 97                -0.196803
# 98                -0.196803
# 99                -0.196803
# 102               -0.196803
# 178               -0.196803
# 100               -0.196803
# 86                -0.196803
# 177               -0.196803
# 174               -0.196803
# 112               -0.196803
# 113               -0.193896
# 111               -0.193458
# 44                -0.190903
# 42                -0.189582
# 43                -0.183514
# 115               -0.176184
# 114               -0.175355
# 45                -0.168333
# 11                -0.158922
# 116               -0.150093
# 92                -0.149184
# 47                -0.148475
# 46                -0.146298
# 91                -0.141247
# 15                -0.140019
# 48                -0.137543
# 13                -0.136957
# 12                -0.135363
# 94                -0.134303
# 93                -0.130136
# 33                -0.129960
# 32                -0.129960
# 21                -0.129960
# 117               -0.121105
# 29                -0.120614
# 3                 -0.112667
# 85                -0.109083
# 82                -0.108567
# 83                -0.107059
# 31                -0.106151
# 172               -0.105894
# 27                -0.103227
# 89                -0.103053
# 2                 -0.097886
# 118               -0.095962
# 76                -0.091964
# 87                -0.091539
# 49                -0.090576
# 51                -0.086131
# 168               -0.085692
# 119               -0.083122
# 78                -0.079156
# 52                -0.078932
# 35                -0.078442
# 19                -0.077329
# 23                -0.075820
# 50                -0.071312
# 28                -0.069639
# 84                -0.069530
# 77                -0.065489
# 53                -0.063755
# 55                -0.062349
# 66                -0.055958
# 0                 -0.055840
# 65                -0.053945
# 54                -0.052122
# 20                -0.046627
# 67                -0.044729
# 95                -0.042956
# 88                -0.042956
# 16                -0.041188
# 8                 -0.040588
# 57                -0.040086
# 81                -0.039660
# 56                -0.036803
# 4                 -0.035654
# 120               -0.034186
# 70                -0.033166
# 5                 -0.030152
# 36                -0.023943
# 68                -0.023726
# 73                -0.023574
# 75                -0.023333
# 72                -0.021803
# 1                 -0.019188
# 37                -0.018849
# 59                -0.012946
# 61                -0.011319
# 80                -0.010756
# 62                -0.007863
# 121               -0.006051
# 58                -0.000456
# 69                 0.003197
# 108                0.003197
# 179                0.003197
# 71                 0.003197
# 164                0.003197
# 63                 0.004111
# 79                 0.007279
# 60                 0.009675
# 74                 0.012500
# 25                 0.012897
# 24                 0.014108
# 169                0.033967
# 7                  0.039523
# 167                0.043197
# 64                 0.043938
# 165                0.045622
# 122                0.051412
# 123                0.051497
# 176                0.053197
# 125                0.060672
# 161                0.066355
# 30                 0.076562
# 17                 0.079872
# 18                 0.081049
# 124                0.081974
# 127                0.083463
# 173                0.088912
# 155                0.123808
# 162                0.129284
# 160                0.130784
# 163                0.136531
# 126                0.139318
# 157                0.143857
# 156                0.156646
# 159                0.164308
# 158                0.164308
# 154                0.166160
# 9                  0.166670
# 128                0.169636
# 6                  0.185782
# 152                0.186693
# 153                0.195868
# 150                0.201571
# 175                0.203197
# 166                0.203197
# 129                0.203854
# 135                0.209269
# 131                0.209505
# 130                0.209888
# 148                0.217132
# 133                0.219864
# 134                0.220822
# 132                0.220992
# 151                0.242222
# 26                 0.245529
# 141                0.251915
# 14                 0.256111
# 170                0.257743
# 147                0.265029
# 149                0.267483
# 10                 0.276467
# 140                0.290801
# 136                0.291386
# 145                0.292226
# 144                0.294051
# 171                0.303197
# 143                0.306847
# 138                0.311295
# 137                0.312325
# 146                0.313333
# 139                0.314776
# 142                0.325550
# 34                 0.332962
# 22                 0.347415

# %% [markdown]
# 11               Female + Never-Married   sex + marital_status       0.037801
# 2                        Female + Black             sex + race       0.060758
# 0                           Female                  sex              0.113678
